# %%
from plots_gifs import get_gif_given_params
import numpy as np

# %%
params_dict = {
        'gamma_r': {'role': 'x_axis', 'value': (.5, 10)},
        'gamma_a': {'role': 'y_axis', 'value': (.5, 10)},
        'sigma_r': {'role': 'const', 'value': .5},
        'sigma_a': {'role': 'const', 'value': .3}
    }

T_list = np.arange(4, 15)
params_list = [params_dict] * len(T_list)

N = 1_000

fig_params = {'m': 9, 'n': 7, 'name': 'Example', 'to_plot': True}

get_gif_given_params(params_list, T_list, N, 'RES_PLOTS/Example_1.gif', fig_params, duration=1005, batch_size=100_000)

# %%
params_list = [
    {
        'gamma_r': {'role': 'x_axis', 'value': (0.01, 10)},
        'gamma_a': {'role': 'y_axis', 'value': (0.01, 10)},
        'sigma_r': {'role': 'const', 'value': 1},
        'sigma_a': {'role': 'const', 'value': x}
    } for x in np.exp(np.linspace(-2.5, 2.5, 51))
]


T_list = [3] * 51
N = 1_000
    
fig_params = {'m': 9, 'n': 7, 'name': 'Example_2_', 'to_plot': True}

get_gif_given_params(params_list, T_list, N, 'RES_PLOTS/Example_2.gif', fig_params, duration=500, batch_size=100_000)

# %%
params_dict = {
        'gamma_r': {'role': 'x_axis', 'value': (0.01, 50)},
        'gamma_a': {'role': 'y_axis', 'value': (0.01, 50)},
        'sigma_r': {'role': 'const', 'value': 9},
        'sigma_a': {'role': 'const', 'value': 9}
    }

T_list = np.arange(1, 22)
params_list = [params_dict] * len(T_list)

N = 1_000

fig_params = {'m': 9, 'n': 7, 'name': 'Example_3_', 'to_plot': True}

get_gif_given_params(params_list, T_list, N, 'RES_PLOTS/Example_3.gif', fig_params, duration=1005, batch_size=4_000)
